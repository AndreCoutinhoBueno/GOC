# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# O aqruivo sem ataque será não será utilizado.

# %%
c=pd.read_csv('~/git/BD/GOC/arquivo_com_ataque.csv')
c=c.sample(10**4)

# %%
c=c.sort_values('hora').reset_index(drop=True)

# %%
c.hora=pd.to_datetime(c.hora).astype(int)

# %%
cg=c.groupby(by=['hora']).ip.count().reset_index()

# %%
sns.relplot(data=cg,x='hora',y='ip')

# %%
ip_max_ind=cg[cg.ip==cg.ip.max()].index[0]

# %%
cg.ip.mean()
# Out:
# 2.221728504776716

# %%
cg=cg.reset_index()

# %%
atack=cg[cg.ip>10]
sns.relplot(data=atack,x='index',y='ip')

# %%
cg=0

# %%
atack=atack.assign(atack=1)

# %%
c=c.merge(atack[['hora','atack']], how='outer')

# %%
c.loc[c.atack.isna(),'atack']=0

# %%
atack=0

# %%
c=c.fillna(0)

# %%
c=c.drop(columns=['tamanho_resposta'])

# %%
c.status_code=c.status_code.astype('object')
c=pd.concat([
    c.select_dtypes(exclude='object'),
    c.select_dtypes(include='object').astype('category')
],axis=1)

# %%
c=pd.get_dummies(c, prefix_sep='~')

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
RFC=RFC()

# %%
from sklearn.model_selection import train_test_split as tts

# %%
train, test=tts(c,test_size=.2)

# %%
c=0

# %%
X_train=train.drop(columns=['atack','hora'])
y_train=train.atack

# %%
train=0

# %%
X_test=test.drop(columns=['atack','hora'])
y_test=test.atack

# %%
RFC.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
test_pred=test.assign(atack_pred=RFC.predict(X_test)).assign(atack=y_test)

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(test_pred.atack,test_pred.atack_pred)
# Out:
# 0.993

# %%
metrics.precision_score(test_pred.atack,test_pred.atack_pred)
# Out:
# 0.9777158774373259

# %%
metrics.recall_score(test_pred.atack,test_pred.atack_pred)
# Out:
# 0.9831932773109243

# %%
test_pred=pd.concat([test_pred.select_dtypes(exclude='bool'),pd.from_dummies(test_pred.select_dtypes('bool'),sep='~')],axis=1)

# %%
test_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 6970 to 3819
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   hora             2000 non-null   int64
#  1   tamanho_request  2000 non-null   int64
#  2   atack            2000 non-null   float64
#  3   atack_pred       2000 non-null   float64
#  4   ip               2000 non-null   object
#  5   metodo           2000 non-null   object
#  6   protocolo        2000 non-null   object
#  7   hostname         2000 non-null   object
#  8   uri              2000 non-null   object
#  9   querystring      2000 non-null   object
#  10  status_code      2000 non-null   object
#  11  f0_              2000 non-null   object
#  12  useragent        2000 non-null   object
#  13  organizacao      2000 non-null   object
#  14  pais             2000 non-null   object
#  15  cidade           2000 non-null   object
#  16  cookie_sessao    2000 non-null   object
#  17  fingerprint1     2000 non-null   object
#  18  fingerprint2     2000 non-null   object
#  19  fingerprint3     2000 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 392.7+ KB

# %%
tpg_sem_prev=test_pred.groupby('hora').ip.count().reset_index()

# %%
tpg_sem_prev=tpg_sem_prev.merge(test_pred[['hora','atack_pred']].drop_duplicates())

# %%
sns.relplot(data=tpg_sem_prev,x='hora',y='ip',hue='atack_pred')

# %%
tpg_com_prev=test_pred[test_pred.atack_pred==0].groupby('hora').ip.count().reset_index()

# %%
tpg_com_prev=tpg_com_prev.merge(test_pred[['hora','atack_pred']].drop_duplicates())

# %%
sns.relplot(data=tpg_com_prev,x='hora',y='ip',hue='atack_pred')
